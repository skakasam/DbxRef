# %%
print("Hello Databricks!")

# %% [markdown]
# # Magic Commands
# - %sql allows to run SQL commands from a notebook
# - %run allows to run/import another notebook within the current notebook
# - %md (like this cell) allows to add a Markdown content to a call (useful for documentation)
# - %fs allows to run file system operation to list all files in a directory

# %%
# %sql
SELECT "Hello Databricks from SQL!"

# %%
# %run "./Includes/Setup"

# %%
print(f"User Name (from ./Includes/Setup.ipynb Notebook) = {full_name}")

# %%
# %fs ls "/Workspace/Users/surya.akasam@gmail.com/Databricks-Certified-Data-Engineer-Associate"

# %%
# dbutils provide useful utilities in Databricks
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("/Workspace/Users/surya.akasam@gmail.com/Databricks-Certified-Data-Engineer-Associate")
display(files)
